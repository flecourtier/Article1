# %% [markdown]
# # Convergence FEM / PINNs+Corr

# %%
# sélection du cas test
testcase = 1
version = 1
param_num = 1

# %% [markdown]
# **Idée :** On se place ici dans un des cas tests proposés : TestCase1,1_v2,2.
#
# On cherche à vérifier les convergences obtenues pour
#
# - FEM standard
# - le PINNs + Correction par addition
#
# On choisira d'effectuer ces convergences en P1,P2 et P3

# %% [markdown]
# ## Imports + Load

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas as pd
import os
import dolfin as df

from scimba.equations.domain import SpaceTensor
from scimba.equations import domain
from modules.solver_fem import FEMSolver
from modules.utils import create_tree

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Using device: cuda
# cuda devices:        1
# cuda current device: 0
# cuda device name:    NVIDIA RTX 2000 Ada Generation Laptop GPU
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %%
if testcase == 1:
    if version == 1:
        from modules.testcases.test_1 import Run_laplacian2D,Poisson_2D
    elif version == 2:
        from modules.testcases.test_1_v2 import Run_laplacian2D,Poisson_2D
    else:
        raise ValueError("Version not found")
    from modules.problem import TestCase1
    problem = TestCase1()
elif testcase == 2:
    from modules.testcases.test_2 import Run_laplacian2D,Poisson_2D
    from modules.problem import TestCase2
    problem = TestCase2()
else:
    raise ValueError("Testcase not found")

result_dir = "../../../results/testcase"+str(testcase)
if version != 1:
    result_dir += "_v"+str(version)
result_dir += "/cvg/"
create_tree(result_dir)
# Out:
# torch loaded; device is cuda

# %%
pde = Poisson_2D()
trainer,u_theta = Run_laplacian2D(pde)
# Out:
# /home/flecourtier/Bureau/Article1
# >> load network /home/flecourtier/Bureau/Article1/networks/test_fe1.pth
# jsbdbshd
# network loaded
# Error  tensor([0.0041])

# %%
def get_param(i):
    params = trainer.pde.parameter_domain.cpu().numpy()
    # pick 1 random parameter
    np.random.seed(0)
    for j in range(i):
        param = [np.random.uniform(params[0][0], params[0][1]), np.random.uniform(params[1][0], params[1][1])]
    param = np.round(param, 2)
    return param

param = get_param(param_num)
print(param)
params = [param]
# Out:
# [0.05 0.22]

# %% [markdown]
# ## Convergence FEM

# %%
def read_csv(testcase,param_num,degree):
    df_FEM = pd.read_csv(result_dir+f'FEM_case{testcase}_param{param_num}_degree{degree}.csv')
    tab_nb_vert_FEM = list(df_FEM['nb_vert'].values)
    tab_h_FEM = list(df_FEM['h'].values)
    tab_err_FEM = list(df_FEM['err'].values)
    
    return df_FEM,tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM

def run_FEM(degree,new_run=False):
    csv_file = result_dir+f'FEM_case{testcase}_param{param_num}_degree{degree}.csv'
    if not new_run and os.path.exists(csv_file):
        df_FEM,tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM = read_csv(testcase,param_num,degree)
        print(f"Read csv file {csv_file}")
    else:
        tab_nb_vert_FEM = [2**i for i in range(4,9)]
        tab_h_FEM = []
        tab_err_FEM = []

        for nb_vert in tab_nb_vert_FEM:
            solver = FEMSolver(nb_cell=nb_vert-1, params=params, problem=problem, degree=degree)
            tab_h_FEM.append(solver.h)
            _,norme_L2 = solver.fem(0)
            print(f"nb_vert={nb_vert}, norme_L2={norme_L2}")
            tab_err_FEM.append(norme_L2)
            
        df_FEM = pd.DataFrame({'nb_vert': tab_nb_vert_FEM, 'h': tab_h_FEM, 'err': tab_err_FEM})
        df_FEM.to_csv(csv_file, index=False)
            
    return df_FEM,tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM

# %%
degree = 1
df_FEM, tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM = run_FEM(degree)
# Out:
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree1.csv

# %%
plt.figure(figsize=(5, 5))

# plot FEM error (L2 norm) as a function of h
for d in [1, 2, 3]:
    print(f"degree={d}")
    df_FEM, tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM = run_FEM(d)
    plt.loglog(df_FEM['nb_vert'], df_FEM['err'], "+-", label='P'+str(d))
    
    # add slope with a triangle
    start = [tab_nb_vert_FEM[1],tab_err_FEM[1]]
    end = [tab_nb_vert_FEM[0],tab_err_FEM[0]]
    third = [end[0],start[1]]
    
    tri_x = [end[0], third[0], start[0], end[0]]
    tri_y = [end[1], third[1], start[1], end[1]]
    plt.plot(tri_x, tri_y, "k--", linewidth=0.5)
    
    slope = (np.log(start[1])-np.log(end[1]))/(np.log(start[0])-np.log(end[0]))
    slope = abs(int(slope.round(0)))

    vert_mid = [(end[0]+third[0])/2., (end[1]+third[1])/2.]
    plt.text(vert_mid[0]+1e-2 , vert_mid[1], str(slope), fontsize=12, ha='left', va='top')
    
plt.xticks(df_FEM['nb_vert'], df_FEM['nb_vert'].round(3).astype(str))
plt.xlabel('nb_vert')
plt.ylabel('L2 norm')
plt.title(f'FEM case{testcase} param{param_num} : {param}')
plt.legend()
plt.savefig(result_dir+f'FEM_case{testcase}_param{param_num}.png')
# Out:
# degree=1
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree1.csv
# degree=2
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree2.csv
# degree=3
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree3.csv

# %%
dict = {}
for d in [1, 2, 3]:
    print(f"degree={d}")
    _, tab_nb_vert_FEM, _, tab_err_FEM = run_FEM(d)
    if d == 1:
        dict['N'] = tab_nb_vert_FEM
    dict[f'P{d}'] = tab_err_FEM
    
df_deg = pd.DataFrame(dict)

csv_file = result_dir+f'FEM_case{testcase}_param{param_num}.csv'
df_deg.to_csv(csv_file, index=False)
# Out:
# degree=1
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree1.csv
# degree=2
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree2.csv
# degree=3
# Read csv file ../../../results/testcase1/cvg/FEM_case1_param1_degree3.csv

# %% [markdown]
# ## Convergence PINNs+Corr

# %%
def get_test_sample(i,solver,trainer,deg_PINNs):
    # get coordinates of the dof
    V_test = df.FunctionSpace(solver.mesh,"CG",deg_PINNs)
    XXYY = V_test.tabulate_dof_coordinates()
    X_test = torch.tensor(XXYY,requires_grad=True)
    X_test = SpaceTensor(X_test,torch.zeros_like(X_test,dtype=int))

    # get parameters
    nb_params = len(trainer.pde.parameter_domain)
    shape = (XXYY.shape[0],nb_params)
    ones = torch.ones(shape)
    mu_test = (torch.Tensor(params[i]).to(device) * ones).to(device)

    return V_test,X_test,mu_test

# %%
degree_PINNs = 10

def read_csv_Corr(testcase,param_num,degree):
    df_Corr = pd.read_csv(result_dir+f'Corr_case{testcase}_param{param_num}_degree{degree}.csv')
    tab_nb_vert_Corr = list(df_Corr['nb_vert'].values)
    tab_h_Corr = list(df_Corr['h'].values)
    tab_err_Corr = list(df_Corr['err'].values)
    
    return df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr

def run_Corr(degree,new_run=False):
    csv_file = result_dir+f'Corr_case{testcase}_param{param_num}_degree{degree}.csv'
    if not new_run and os.path.exists(csv_file):
        df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr = read_csv_Corr(testcase,param_num,degree)
        print(f"Read csv file {csv_file}")
    else:
        tab_nb_vert_Corr = [2**i for i in range(4,9)]
        # tab_nb_vert_Corr = [5*i for i in range(2,7)]
        tab_h_Corr = []
        tab_err_Corr = []

        for nb_vert in tab_nb_vert_Corr:
            solver = FEMSolver(nb_cell=nb_vert-1, params=params, problem=problem, degree=degree)
            tab_h_Corr.append(solver.h)
            
            V_test,X_test,mu_test = get_test_sample(0,solver,trainer,degree_PINNs)
            pred = u_theta.setup_w_dict(X_test, mu_test)
            phi_tild = pred["w"][:,0].cpu().detach().numpy()
            
            u_PINNs = df.Function(V_test)
            u_PINNs.vector()[:] = phi_tild.copy()
            
            _,_,norme_L2 = solver.corr_add(0,u_PINNs)
            print(f"nb_vert={nb_vert}, norme_L2={norme_L2}")
            tab_err_Corr.append(norme_L2)
            
        df_Corr = pd.DataFrame({'nb_vert': tab_nb_vert_Corr, 'h': tab_h_Corr, 'err': tab_err_Corr})
        df_Corr.to_csv(csv_file, index=False)
            
    return df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr

# %%
plt.figure(figsize=(5, 5))

# plot Corr error (L2 norm) as a function of h
for d in [1, 2, 3]:
    print(f"degree={d}")
    df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr = run_Corr(d,new_run=True)
    plt.loglog(df_Corr['nb_vert'], df_Corr['err'], "+-", label='P'+str(d))
    
    # add slope with a triangle
    start = [tab_nb_vert_Corr[1],tab_err_Corr[1]]
    end = [tab_nb_vert_Corr[0],tab_err_Corr[0]]
    third = [end[0],start[1]]
    
    tri_x = [end[0], third[0], start[0], end[0]]
    tri_y = [end[1], third[1], start[1], end[1]]
    plt.plot(tri_x, tri_y, "k--", linewidth=0.5)
    
    slope = (np.log(start[1])-np.log(end[1]))/(np.log(start[0])-np.log(end[0]))
    slope = abs(int(slope.round(0)))

    vert_mid = [(end[0]+third[0])/2., (end[1]+third[1])/2.]
    plt.text(vert_mid[0]+1e-2 , vert_mid[1], str(slope), fontsize=12, ha='left', va='top')

plt.xticks(df_Corr['nb_vert'], df_Corr['nb_vert'].round(3).astype(str), minor=True)
plt.xlabel("nb_vert")
plt.ylabel('L2 norm')
plt.legend()
plt.title(f'Corr case{testcase} param{param_num} : {param}')
plt.savefig(result_dir+f'Corr_case{testcase}_param{param_num}.png')
# Out:
# degree=1
# hmax =  0.29619219587722484
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'extended_nonpositive'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 for d in [1, 2, 3]:
#       5     print(f"degree={d}")
# ----> 6     df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr = run_Corr(d,new_run=True)
#       7     plt.loglog(df_Corr['nb_vert'], df_Corr['err'], "+-", label='P'+str(d))
#       9     # add slope with a triangle
#
# Cell In[16], line 33, in run_Corr(degree, new_run)
#      30 u_PINNs = df.Function(V_test)
#      31 u_PINNs.vector()[:] = phi_tild.copy()
# ---> 33 _,_,norme_L2 = solver.corr_add(0,u_PINNs)
#      34 print(f"nb_vert={nb_vert}, norme_L2={norme_L2}")
#      35 tab_err_Corr.append(norme_L2)
#
# File ~/Bureau/Article1/src/modules/solver_fem.py:145, in FEMSolver.corr_add(self, i, phi_tild, nonexactBC)
#     142 l = f_tild * v * self.dx
#     144 A = df.assemble(a)
# --> 145 L = df.assemble(l)
#     146 bc.apply(A, L)
#     148 end = time.time()
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dolfin/fem/assembling.py:198, in assemble(form, tensor, form_compiler_parameters, add_values, finalize_tensor, keep_diagonal, backend)
#     196     dolfin_form = form
#     197 else:
# --> 198     dolfin_form = _create_dolfin_form(form, form_compiler_parameters)
#     200 # Create tensor
#     201 comm = dolfin_form.mesh().mpi_comm()
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dolfin/fem/assembling.py:56, in _create_dolfin_form(form, form_compiler_parameters, function_spaces)
#      54     return form
#      55 elif isinstance(form, ufl.Form):
# ---> 56     return Form(form,
#      57                 form_compiler_parameters=form_compiler_parameters,
#      58                 function_spaces=function_spaces)
#      59 else:
#      60     raise TypeError("Invalid form type %s" % (type(form),))
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dolfin/fem/form.py:43, in Form.__init__(self, form, **kwargs)
#      40 if form_compiler_parameters is None:
#      41     form_compiler_parameters = {"external_include_dirs": dolfin_pc["include_dirs"]}
# ---> 43 ufc_form = ffc_jit(form, form_compiler_parameters=form_compiler_parameters,
#      44                    mpi_comm=mesh.mpi_comm())
#      45 ufc_form = cpp.fem.make_ufc_form(ufc_form[0])
#      47 function_spaces = kwargs.get("function_spaces")
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dolfin/jit/jit.py:47, in mpi_jit_decorator.<locals>.mpi_jit(*args, **kwargs)
#      45 # Just call JIT compiler when running in serial
#      46 if MPI.size(mpi_comm) == 1:
# ---> 47     return local_jit(*args, **kwargs)
#      49 # Default status (0 == ok, 1 == fail)
#      50 status = 0
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dolfin/jit/jit.py:97, in ffc_jit(ufl_form, form_compiler_parameters)
#      95 p.update(dict(parameters["form_compiler"]))
#      96 p.update(form_compiler_parameters or {})
# ---> 97 return ffc.jit(ufl_form, parameters=p)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/jitcompiler.py:217, in jit(ufl_object, parameters, indirect)
#     214 kind, module_name = compute_jit_prefix(ufl_object, parameters)
#     216 # Inspect cache and generate+build if necessary
# --> 217 module = jit_build(ufl_object, module_name, parameters)
#     219 # Raise exception on failure to build or import module
#     220 if module is None:
#     221     # TODO: To communicate directory name here, need dijitso params to call
#     222     #fail_dir = dijitso.cache.create_fail_dir_path(signature, dijitso_cache_params)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/jitcompiler.py:130, in jit_build(ufl_object, module_name, parameters)
#     123 params = dijitso.validate_params({
#     124     "cache": cache_params,
#     125     "build": build_params,
#     126     "generator": parameters,  # ffc parameters, just passed on to jit_generate
#     127 })
#     129 # Carry out jit compilation, calling jit_generate only if needed
# --> 130 module, signature = dijitso.jit(jitable=ufl_object,
#     131                                 name=module_name,
#     132                                 params=params,
#     133                                 generate=jit_generate)
#     134 return module
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/dijitso/jit.py:165, in jit(jitable, name, params, generate, send, receive, wait)
#     161     error("Please provide only one of generate or receive.")
#     163 elif generate:
#     164     # 1) Generate source code
# --> 165     header, source, dependencies = generate(jitable, name, signature, params["generator"])
#     166     # Ensure we got unicode from generate
#     167     header = as_unicode(header)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/jitcompiler.py:65, in jit_generate(ufl_object, module_name, signature, parameters)
#      62 elif isinstance(ufl_object, ufl.Mesh):
#      63     compile_object = compile_coordinate_mapping
# ---> 65 code_h, code_c, dependent_ufl_objects = compile_object(ufl_object,
#      66         prefix=module_name, parameters=parameters, jit=True)
#      68 # Jit compile dependent objects separately,
#      69 # but pass indirect=True to skip instantiating objects.
#      70 # (this is done in here such that it's only triggered
#      71 # if parent jit module is missing, and it's done after
#      72 # compile_object because some misformed ufl objects may
#      73 # require analysis to determine (looking at you Expression...))
#      74 dependencies = []
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/compiler.py:142, in compile_form(forms, object_names, prefix, parameters, jit)
#     139 def compile_form(forms, object_names=None,
#     140                  prefix="Form", parameters=None, jit=False):
#     141     """This function generates UFC code for a given UFL form or list of UFL forms."""
# --> 142     return compile_ufl_objects(forms, "form", object_names,
#     143                                prefix, parameters, jit)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/compiler.py:190, in compile_ufl_objects(ufl_objects, kind, object_names, prefix, parameters, jit)
#     188 # Stage 2: intermediate representation
#     189 cpu_time = time()
# --> 190 ir = compute_ir(analysis, prefix, parameters, jit)
#     191 _print_timing(2, time() - cpu_time)
#     193 # Stage 3: optimization
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/representation.py:182, in compute_ir(analysis, prefix, parameters, jit)
#     180 # Compute and flatten representation of integrals
#     181 info("Computing representation of integrals")
# --> 182 irs = [_compute_integral_ir(fd, form_id, prefix, element_numbers, classnames, parameters, jit)
#     183        for (form_id, fd) in enumerate(form_datas)]
#     184 ir_integrals = list(chain(*irs))
#     186 # Compute representation of forms
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/representation.py:182, in <listcomp>(.0)
#     180 # Compute and flatten representation of integrals
#     181 info("Computing representation of integrals")
# --> 182 irs = [_compute_integral_ir(fd, form_id, prefix, element_numbers, classnames, parameters, jit)
#     183        for (form_id, fd) in enumerate(form_datas)]
#     184 ir_integrals = list(chain(*irs))
#     186 # Compute representation of forms
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/representation.py:455, in _compute_integral_ir(form_data, form_id, prefix, element_numbers, classnames, parameters, jit)
#     452 r = pick_representation(itg_data.metadata["representation"])
#     454 # Compute representation
# --> 455 ir = r.compute_integral_ir(itg_data,
#     456                            form_data,
#     457                            form_id,     # FIXME: Can we remove this?
#     458                            element_numbers,
#     459                            classnames,
#     460                            parameters)
#     462 # Remember jit status
#     463 ir["jit"] = jit
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/uflacs/uflacsrepresentation.py:43, in compute_integral_ir(itg_data, form_data, form_id, element_numbers, classnames, parameters)
#      40 info("Computing uflacs representation")
#      42 # Initialise representation
# ---> 43 ir = initialize_integral_ir("uflacs", itg_data, form_data, form_id)
#      45 # Store element classnames
#      46 ir["classnames"] = classnames
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/representationutils.py:198, in initialize_integral_ir(representation, itg_data, form_data, form_id)
#     185 # Set number of cells if not set  TODO: Get automatically from number of domains
#     186 num_cells = itg_data.metadata.get("num_cells")
#     188 return {"representation": representation,
#     189         "integral_type": itg_data.integral_type,
#     190         "subdomain_id": itg_data.subdomain_id,
#     191         "form_id": form_id,
#     192         "rank": form_data.rank,
#     193         "geometric_dimension": form_data.geometric_dimension,
#     194         "topological_dimension": tdim,
#     195         "entitytype": entitytype,
#     196         "num_facets": cell.num_facets(),
#     197         "num_vertices": cell.num_vertices(),
# --> 198         "needs_oriented": needs_oriented_jacobian(form_data),
#     199         "num_cells": num_cells,
#     200         "enabled_coefficients": itg_data.enabled_coefficients,
#     201         }
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/representationutils.py:151, in needs_oriented_jacobian(form_data)
#     147 def needs_oriented_jacobian(form_data):
#     148     # Check whether this form needs an oriented jacobian (only forms
#     149     # involgin contravariant piola mappings seem to need it)
#     150     for ufl_element in form_data.unique_elements:
# --> 151         element = create_element(ufl_element)
#     152         if "contravariant piola" in element.mapping():
#     153             return True
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/fiatinterface.py:100, in create_element(ufl_element)
#      98 # Create regular FIAT finite element
#      99 if isinstance(ufl_element, ufl.FiniteElement):
# --> 100     element = _create_fiat_element(ufl_element)
#     102 # Create mixed element (implemented by FFC)
#     103 elif isinstance(ufl_element, ufl.MixedElement):
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/ffc/fiatinterface.py:198, in _create_fiat_element(ufl_element)
#     196             element = ElementClass(fiat_cell)
#     197         else:
# --> 198             element = ElementClass(fiat_cell, degree)
#     200 # Consistency check between UFL and FIAT elements.
#     201 if element.value_shape() != ufl_element.reference_value_shape():
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/lagrange.py:54, in Lagrange.__init__(self, ref_el, degree)
#      53 def __init__(self, ref_el, degree):
# ---> 54     poly_set = polynomial_set.ONPolynomialSet(ref_el, degree)
#      55     dual = LagrangeDualSet(ref_el, degree)
#      56     formdegree = 0  # 0-form
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/polynomial_set.py:174, in ONPolynomialSet.__init__(self, ref_el, degree, shape)
#     171 v = numpy.transpose(expansion_set.tabulate(degree, pts))
#     172 vinv = numpy.linalg.inv(v)
# --> 174 dv = expansion_set.tabulate_derivatives(degree, pts)
#     175 dtildes = [[[a[1][i] for a in dvrow] for dvrow in dv]
#     176            for i in range(sd)]
#     178 dmats = [numpy.dot(vinv, numpy.transpose(dtilde))
#     179          for dtilde in dtildes]
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/expansions.py:260, in TriangleExpansionSet.tabulate_derivatives(self, n, pts)
#     258 def tabulate_derivatives(self, n, pts):
#     259     order = 1
# --> 260     data = _tabulate_dpts(self._tabulate, 2, n, order, numpy.array(pts))
#     261     # Put data in the required data structure, i.e.,
#     262     # k-tuples which contain the value, and the k-1 derivatives
#     263     # (gradient, Hessian, ...)
#     264     m = data[0].shape[0]
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/expansions.py:102, in _tabulate_dpts(tabulator, D, n, order, pts)
#      97         data[r][i] = \
#      98             numpy.array(evaluate_lambda(deriv_lambda, pts.T)).T
#      99         # Symbolically compute the next derivative.
#     100         # This actually happens once too many here; never mind for
#     101         # now.
# --> 102         phi.append(form_derivative(phi[-1]))
#     103 return data
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/expansions.py:48, in _tabulate_dpts.<locals>.form_derivative(F)
#      46 out = []
#      47 try:
# ---> 48     out = [sympy.diff(F, X[j]) for j in range(D)]
#      49 except (AttributeError, ValueError):
#      50     # Intercept errors like
#      51     #  AttributeError: 'list' object has no attribute
#      52     #  'free_symbols'
#      53     for f in F:
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/FIAT/expansions.py:48, in <listcomp>(.0)
#      46 out = []
#      47 try:
# ---> 48     out = [sympy.diff(F, X[j]) for j in range(D)]
#      49 except (AttributeError, ValueError):
#      50     # Intercept errors like
#      51     #  AttributeError: 'list' object has no attribute
#      52     #  'free_symbols'
#      53     for f in F:
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/function.py:2482, in diff(f, *symbols, **kwargs)
#    2418 """
#    2419 Differentiate f with respect to symbols.
#    2420
#    (...)
#    2479
#    2480 """
#    2481 if hasattr(f, 'diff'):
# -> 2482     return f.diff(*symbols, **kwargs)
#    2483 kwargs.setdefault('evaluate', True)
#    2484 return _derivative_dispatch(f, *symbols, **kwargs)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/expr.py:3586, in Expr.diff(self, *symbols, **assumptions)
#    3584 def diff(self, *symbols, **assumptions):
#    3585     assumptions.setdefault("evaluate", True)
# -> 3586     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/function.py:1909, in _derivative_dispatch(expr, *variables, **kwargs)
#    1907     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1908     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1909 return Derivative(expr, *variables, **kwargs)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/function.py:1438, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1435         expr *= old_v.diff(old_v)
#    1437 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
# -> 1438 if obj is not None and obj.is_zero:
#    1439     return obj
#    1441 nderivs += count
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/add.py:845, in Add._eval_is_extended_nonpositive(self)
#     843 if not self.is_number:
#     844     c, a = self.as_coeff_Add()
# --> 845     if not c.is_zero and a.is_extended_nonpositive:
#     846         from .exprtools import _monotonic_sign
#     847         v = _monotonic_sign(a)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/anaconda3/envs/phifem_scimba_2/lib/python3.9/site-packages/sympy/core/assumptions.py:586, in _ask(fact, obj)
#     577     return fact_value
#     579 # Extend the queue with other facts that might determine fact_i. Here
#     580 # we randomise the order of the facts that are checked. This should not
#     581 # lead to any non-determinism if all handlers are logically consistent
#    (...)
#     584 # call to shuffle. These are pushed to the back of the queue meaning
#     585 # that the inference graph is traversed in breadth-first order.
# --> 586 new_facts_to_check = list(_assume_rules.prereq[fact_i] - facts_queued)
#     587 shuffle(new_facts_to_check)
#     588 facts_to_check.extend(new_facts_to_check)
#
# KeyboardInterrupt:

# %%
dict = {}
for d in [1, 2, 3]:
    print(f"degree={d}")
    _, tab_nb_vert_Corr, _, tab_err_Corr = run_Corr(d)
    if d == 1:
        dict['N'] = tab_nb_vert_Corr
    dict[f'P{d}'] = tab_err_Corr
    
df_deg_Corr = pd.DataFrame(dict)

csv_file = result_dir+f'Corr_case{testcase}_param{param_num}.csv'
df_deg_Corr.to_csv(csv_file, index=False)
# Out:
# degree=1
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree1.csv
# degree=2
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree2.csv
# degree=3
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree3.csv

# %% [markdown]
# ## Plots

# %%
plt.figure(figsize=(5, 5))

# plot FEM error (L2 norm) as a function of h
for d in [1, 2, 3]:
    print(f"degree={d}")
    df_FEM, tab_nb_vert_FEM, tab_h_FEM, tab_err_FEM = run_FEM(d)
    plt.loglog(df_FEM['nb_vert'], df_FEM['err'], "+-", label='FEM P'+str(d))

# plot Corr error (L2 norm) as a function of h
for d in [1, 2, 3]:
    print(f"degree={d}")
    df_Corr,tab_nb_vert_Corr, tab_h_Corr, tab_err_Corr = run_Corr(d)
    plt.loglog(df_Corr['nb_vert'], df_Corr['err'], ".--", label='Corr P'+str(d))

plt.xticks(df_Corr['nb_vert'], df_Corr['nb_vert'].round(3).astype(str), minor=False)
plt.xlabel("N")
plt.ylabel('L2 norm')
plt.legend()
plt.title(f'FEM + Corr case{testcase} param{param_num} : {param}')
plt.savefig(result_dir+f'FEM-Corr_case{testcase}_param{param_num}.png')
# Out:
# degree=1
# Read csv file ../results/testcase2/cvg/FEM_case2_param2_degree1.csv
# degree=2
# Read csv file ../results/testcase2/cvg/FEM_case2_param2_degree2.csv
# degree=3
# Read csv file ../results/testcase2/cvg/FEM_case2_param2_degree3.csv
# degree=1
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree1.csv
# degree=2
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree2.csv
# degree=3
# Read csv file ../results/testcase2/cvg/Corr_case2_param2_degree3.csv
